# %% [markdown]
# # Create a simple DataFrame

# %%
data = [("iPhone", 999), ("Samsung", 799), ("MacBook", 1299)]
df = spark.createDataFrame(data, ["product", "price"])
df.show()
# Out:
# +-------+-----+
# |product|price|
# +-------+-----+
# | iPhone|  999|
# |Samsung|  799|
# |MacBook| 1299|
# +-------+-----+

# %% [markdown]
# # Filter expensive products over 1000

# %%
df.filter(df.price > 1000).show()
# Out:
# +-------+-----+
# |product|price|
# +-------+-----+
# |MacBook| 1299|
# +-------+-----+
